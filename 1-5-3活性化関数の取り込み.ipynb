# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.array(
    [[7],
     [4]
     ])

# %%
x
# Out:
# array([[7],
#        [4]])

# %%
w = np.array([
    [7,4],
    [-2,-3]
])

# %%
w
# Out:
# array([[ 7,  4],
#        [-2, -3]])

# %%
b = np.array([
    [1],
    [25]
])

# %%
b
# Out:
# array([[ 1],
#        [25]])

# %%
a = w.dot(x)+b

# %%
a
# Out:
# array([[66],
#        [-1]])

# %%
def sigmoid(x):
  return 1/(1+np.exp(-x))

# %%
sigmoid(9)
# Out:
# 0.9998766054240137

# %%
y = sigmoid(a)

# %%
y
# Out:
# array([[1.        ],
#        [0.26894142]])
