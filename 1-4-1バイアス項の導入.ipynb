# %%
import numpy as np

# %%
a = np.array([[1],[3]])

# %%
a
# Out:
# array([[1],
#        [3]])

# %%
b = np.array([[2],[4]])

# %%
b
# Out:
# array([[2],
#        [4]])

# %%
a+b
# Out:
# array([[3],
#        [7]])

# %%
c = np.array([[1,2],[3,4]])

# %%
c
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
d = np.array([[5,6],[7,8]])

# %%
d
# Out:
# array([[5, 6],
#        [7, 8]])

# %%
c+d
# Out:
# array([[ 6,  8],
#        [10, 12]])

# %% [markdown]
# バイアスまで含めた順伝播の問題

# %%
x = np.array([[7],[8]])

# %%
x
# Out:
# array([[7],
#        [8]])

# %%
w = np.array([[3,5],[4,2]])

# %%
w
# Out:
# array([[3, 5],
#        [4, 2]])

# %%
b = np.array([[1],[1]])

# %%
b
# Out:
# array([[1],
#        [1]])

# %%
w.dot(x)+b
# Out:
# array([[62],
#        [45]])

# %% [markdown]
# 以下は復習

# %%
import numpy as np

# %%
a=np.array([
    [1],
    [3]
         ])

# %%
a
# Out:
# array([[1],
#        [3]])

# %%
b = np.array([
    [2],
    [4]
])

# %%
b
# Out:
# array([[2],
#        [4]])

# %%
a+b
# Out:
# array([[3],
#        [7]])

# %%
w = np.array([[3,5],[4,2]])

# %%
w
# Out:
# array([[3, 5],
#        [4, 2]])

# %%
x = np.array([[7],[8]])

# %%
x
# Out:
# array([[7],
#        [8]])

# %%
c = w.dot(x)+np.array([[1],[1]])

# %%
c
