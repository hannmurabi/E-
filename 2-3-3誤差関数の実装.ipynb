# %% [markdown]
# 二乗和誤差を定義する

# %%
import numpy as np

def mean_squared_error(y,t):
  return 0.5 * np.sum((y-t)**2)

# %%
y = np.array([0.8,0.2])

# %%
t = np.array([1,0])

# %%
E = mean_squared_error(y,t)
E
# Out:
# 0.039999999999999994

# %%
print( 0.5 * (0.57-1)**2)
# Out:
# 0.09245000000000002
