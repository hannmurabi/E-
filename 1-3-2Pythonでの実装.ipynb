# %%
import numpy as np

# %%
x=np.array([1,2])

# %%
x
# Out:
# array([1, 2])

# %%
w=np.array([[4,8] ,[6,3]])

# %%
w
# Out:
# array([[4, 8],
#        [6, 3]])

# %%
x.dot(w)
# Out:
# array([16, 14])

# %%
a=np.array([1,4,7])

# %%
a
# Out:
# array([1, 4, 7])

# %%
b=np.array([
    [2,8,7],
    [1,9,3],
    [6,4,0]
    ])

# %%
b
# Out:
# array([[2, 8, 7],
#        [1, 9, 3],
#        [6, 4, 0]])

# %%
a.dot(b)
# Out:
# array([48, 72, 19])
